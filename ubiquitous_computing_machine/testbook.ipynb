# %%
from ubiquitous_computing_machine.part_1e import *
from ubiquitous_computing_machine.utils import feature_names, get_data

# %%
# Out:
# +------+----------------+----------------+------------+
# |   df |   Spline Order |   Training MSE |   Test MSE |
# +======+================+================+============+
# |    2 |              1 |        1.40291 |    1.52259 |
# +------+----------------+----------------+------------+
# |    5 |              4 |        1.39526 |    1.52361 |
# +------+----------------+----------------+------------+
# |    4 |              3 |        1.39501 |    1.52436 |
# +------+----------------+----------------+------------+
# |    3 |              2 |        1.39048 |    1.52486 |
# +------+----------------+----------------+------------+
# |    5 |              3 |        1.35897 |    1.52833 |
# +------+----------------+----------------+------------+
# |    6 |              4 |        1.36097 |    1.53556 |
# +------+----------------+----------------+------------+
# |    5 |              1 |        1.31898 |    1.56539 |
# +------+----------------+----------------+------------+
# |    5 |              2 |        1.31701 |    1.57963 |
# +------+----------------+----------------+------------+
# |    8 |              4 |        1.30036 |    1.59107 |
# +------+----------------+----------------+------------+
# |    8 |              3 |        1.26446 |    1.61124 |
# +------+----------------+----------------+------------+
# |    8 |              1 |        1.16484 |    1.63112 |
# +------+----------------+----------------+------------+
# |    8 |              2 |        1.20391 |    1.65146 |
# +------+----------------+----------------+------------+
